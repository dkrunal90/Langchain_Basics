# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
# Langsmith Tracking
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_PROJECT']=os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(model="gpt-4o")
print(llm)
# Out:
# profile={'max_input_tokens': 128000, 'max_output_tokens': 16384, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True} client=<openai.resources.chat.completions.completions.Completions object at 0x10e16b640> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x10e16aa40> root_client=<openai.OpenAI object at 0x10e16add0> root_async_client=<openai.AsyncOpenAI object at 0x10e16a260> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True

# %%
## Input and Output example

result=llm.invoke("What is generative AI?")

# %%
print("Result: ", result)
# Out:
# Result:  content='Generative AI refers to a category of artificial intelligence algorithms and models designed to generate new content, such as text, images, audio, or other data forms. Unlike traditional AI models, which are often used for classification or prediction tasks, generative AI models create new data instances that resemble existing data. \n\nSome key types of generative AI include:\n\n1. **Generative Adversarial Networks (GANs):** A model consisting of two neural networks—a generator and a discriminator—that are trained together. The generator creates new data instances, while the discriminator evaluates them. The goal is for the generator to produce data that is indistinguishable from real data.\n\n2. **Variational Autoencoders (VAEs):** These are probabilistic models used for generating new data points by learning the underlying distribution of the training data. They are often used for tasks like image generation.\n\n3. **Transformer-based Models:** Such as GPT (Generative Pre-trained Transformer) and its variations (e.g., GPT-3, GPT-4), which are used primarily for text generation tasks. These models are trained on large corpora and can generate coherent text based on a given prompt.\n\n4. **Diffusion Models:** These are a newer class of generative models that gradually transform noise into structured data, often used for generating high-fidelity images.\n\nGenerative AI has numerous applications across various fields, including content creation, art, design, gaming, virtual reality, and more. It is a rapidly advancing area of AI research and development, offering innovative ways to create and manipulate digital content.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 317, 'prompt_tokens': 13, 'total_tokens': 330, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-Cpo82hO0LT8xoh84Jje0ibpITla5X', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b496d-48d9-7391-a5a9-3452c8c577f5-0' usage_metadata={'input_tokens': 13, 'output_tokens': 317, 'total_tokens': 330, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
## Prompt template example
from langchain_core.prompts import ChatPromptTemplate

prompt=ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer. Provide me answers based on the question"),
        ("user","{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer. Provide me answers based on the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain=prompt | llm

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print("Response: ", response)
# Out:
# Response:  content='Langsmith is a platform developed by Langchain, designed to help developers build, evaluate, and monitor applications powered by large language models (LLMs). It offers a robust set of tools that simplify the process of constructing, testing, and deploying language model-driven applications. Langsmith is particularly beneficial for developers working with generative AI, as it supports the evaluation and performance optimization of these models in various applications. The platform emphasizes user-friendliness and efficiency, making it easier for developers to experiment and iterate with different model configurations and integrations.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 107, 'prompt_tokens': 33, 'total_tokens': 140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CpoHWaPX4f4fMdd3UYNpaD2BXwZ95', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019b4976-4203-7e90-aeff-b180698232b1-0' usage_metadata={'input_tokens': 33, 'output_tokens': 107, 'total_tokens': 140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## stroutput parser

from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt | llm | output_parser

response=chain.invoke({"input":"Can you tell me about Langsmith?"})
print("Response: ", response)
# Out:
# Response:  Langsmith is a platform designed to enhance the experience of developing with large language models (LLMs). It offers tools for testing, debugging, and monitoring applications that integrate LLMs, aiming to bridge the gap between prototype and production. Key features of Langsmith include:
#
# 1. **Comprehensive Tracing**: It provides detailed traces of LLM-powered applications, which help in understanding how prompts and chains of interactions evolve. This is crucial for debugging and refining applications.
#
# 2. **Evaluation Metrics**: Langsmith allows developers to evaluate their LLM applications through custom metrics and benchmarks. This helps in assessing the performance and accuracy of models, enabling more informed decisions.
#
# 3. **Monitoring and Logging**: With robust monitoring capabilities, Langsmith enables the tracking of application usage and performance over time. This aids in identifying patterns, potential issues, and ensuring reliability.
#
# 4. **Integration Support**: It supports various popular LLM frameworks and can integrate with existing workflows, making it easier for developers to adopt without disruptive changes to their processes.
#
# Overall, Langsmith is geared towards developers looking to build scalable, reliable, and efficient applications using large language models by providing the necessary infrastructure and tools to manage the complexities involved.
